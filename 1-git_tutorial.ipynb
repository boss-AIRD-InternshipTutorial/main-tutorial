# %% [markdown]
# # 0 实干派 vs. 学院派
#
# 代表产出：系统架构+代码 vs. 算法+专利+论文
#
# 侧重点：业务+开发  vs.  方法论+算法
#
# 推荐阅读：《设计模式》（高内聚低耦合、稳健的系统）  vs.  大量论文

# %% [markdown]
# # 1 git、vscode、conda环境安装
#
# 默认自行学习该部分内容。
#
# 电脑右键有git bash，github有独立账户。
#
# 参考：
#
# 1、什么是git：团队代码管理、分布式版本控制系统。
#
# 2、 Git 安装教程+GitHub文件上传全流程： https://blog.csdn.net/m0_63244368/article/details/146210853
#
# 3、VS Code + Git + GitHub教程：https://blog.csdn.net/Karesis/article/details/146198545
#
# 4、ipynb学习——比较好用的python入门编译器。

# %% [markdown]
# # 2、 github创建repository
#
# 右上角头像 -> Your repositories -> New
#
# ![image.png](attachment:image.png)
#
# Code -> SSH复制
#
# 本地Git bash -> git clone
#
# 不成功

# %% [markdown]
# # 3、SSH 认证
#
# 1、给git自己的用户名和邮箱：
#
#  因为Git是分布式版本控制系统，所以需要填写用户名和邮箱作为一个标识。
#
# `git config --global user.name "你的名字"`
#
# `git config --global user.email "你的邮箱地址"`
#
# ![image.png](attachment:image.png)
#
# 2、生成 SSH 密钥对接github
#
# 参考：https://blog.csdn.net/m0_63244368/article/details/146210853 2.1部分
#
# `ssh-keygen -t rsa -C "your-email@example.com"`
#
# 全过程回车：
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 4、clone代码仓
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5、修改文件、提交文件（commit）
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 6、 vscode简化上述步骤
#
#  我的习惯是：一个仓库文件夹单独启动一个VC窗口。
#
#  ![image.png](attachment:image.png)
#
#  ![image-2.png](attachment:image-2.png)
#
#  ![77e6dd84f0bf5474f8a000fcb20561ad.png](attachment:77e6dd84f0bf5474f8a000fcb20561ad.png)
#
#  ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 直接在vscode登录github账户
#
# 参考：https://blog.csdn.net/Karesis/article/details/146198545

# %% [markdown]
# # 7、fork
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 8、下一步学习
#
# - 其他git命令：分支切换、rebase
#
# - 熟练使用vscode查看代码
#
# - 使用ipynb
#
# - 大模型选型
#
# https://huggingface.co/models

# %%
test = 'aaaa'
import numpy as np
